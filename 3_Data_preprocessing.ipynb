# %% [markdown]
# ### **4. DATA PRE-PROCESSING FOR APPLE STOCKS**

# %%
# Function to get the stock price of an individual company we are focusing on to do the stock price prediction
def individual_stock(price_df, name):
    return pd.DataFrame({'Date': price_df['Date'], 'Close': price_df[name]})

# %%
# Let us consider Apple's stock price
df_stockprice= individual_stock(df_stock_price, 'AAPL')
df_stockprice
# Out:
#             Date       Close
# 0     2012-01-12   60.198570
# 1     2012-01-13   59.972858
# 2     2012-01-17   60.671429
# 3     2012-01-18   61.301430
# 4     2012-01-19   61.107143
# ...          ...         ...
# 2154  2020-08-05  440.250000
# 2155  2020-08-06  455.609985
# 2156  2020-08-07  444.450012
# 2157  2020-08-10  450.910004
# 2158  2020-08-11  437.500000
#
# [2159 rows x 2 columns]

# %%
#Plotting the apple stock price
interactive_plot(df_stockprice, 'Stock Price for Apple')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="85b014b9-faca-45bf-a78d-00c74012c229" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("85b014b9-faca-45bf-a78d-00c74012c229")) {
#                     Plotly.newPlot(
#                         '85b014b9-faca-45bf-a78d-00c74012c229',
# ...

# %%
# Drop date column 
df_apple= df_stockprice.drop(columns = ['Date'])
df_apple
# Out:
#            Close
# 0      60.198570
# 1      59.972858
# 2      60.671429
# 3      61.301430
# 4      61.107143
# ...          ...
# 2154  440.250000
# 2155  455.609985
# 2156  444.450012
# 2157  450.910004
# 2158  437.500000
#
# [2159 rows x 1 columns]

# %%
# Scale the data using Min Max scalar

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
df_price_scaled = scaler.fit_transform(df_apple)

print(df_price_scaled.shape)
df_price_scaled
# Out:
# (2159, 1)
# array([[0.01102638],
#        [0.01046185],
#        [0.01220906],
#        ...,
#        [0.97208751],
#        [0.98824476],
#        [0.95470465]])

# %%
# splitting dataset into train and test split
training_size=int(0.65*len(df_price_scaled))
test_size=len(df_price_scaled)-training_size
train_data,test_data=df_price_scaled[0:training_size,:],df_price_scaled[training_size:len(df_price_scaled),:1]
print(train_data.shape, test_data.shape)
# Out:
# (1403, 1) (756, 1)

# %%
# convert an array of values into a dataset matrix
import numpy as np

def create_dataset(dataset, time_step):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 1
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)
print(train_data.shape,test_data.shape)
# Out:
# (1403, 1) (756, 1)

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1401, 1) (1401,)
# (754, 1) (754,)

# %%
# Use random seed
from numpy.random import seed
seed(92)

# Forming the training and testing data
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1302, 100) (1302,)
# (655, 100) (655,)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (1302, 100, 1) (1302,)
# (655, 100, 1) (655,)
